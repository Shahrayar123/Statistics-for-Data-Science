# %% [markdown]
# #### **To check whether data is normally distributed or not we check**
# - **Skewness (s)**
#   - If s = 0 ---------------- Data is normally distributed
#   - If s > 0 ---------------- Data is +vely skewed
#   - If s < 0 ---------------- Data is -vely skewed
#
#     - **-1 < s < 1**
#
#     ![skewness.png](data:image/png;base64,...)
#
# - **Kurtosis (k)**
#   - If k = 0 ---------------- Data is normally distributed
#   - If k > 0 ---------------- +ve kortosis
#   - If k < 0 ---------------- -ve kortosis
#
#     - **-1 < k < 1**
#
#     ![k.jpg](data:image/jpeg;base64,...)
#
# ![kort.png](data:image/png;base64,...)
#
#
# ![kortosis.gif](data:image/gif;base64,...)

# %% [markdown]
# ---

# %%
ages = [10,13,14,16,15,17,18,19,20,22,23,25,26,29,30]

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import seaborn as sbn
from scipy import stats

# %%
print(f"Skewness of age is: {stats.skew(ages)}")
print(f"Kurtosis of age is: {stats.kurtosis(ages)}")
# Out:
# Skewness of age is: 0.21764451198866752
# Kurtosis of age is: -0.9361980394005105

# %%
sbn.distplot(ages)

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ---

# %%
ages = [10,13,10,14,35,80,81,81,80,81,81,40,45,50,53,59,60,]

print(f"Skewness of age is: {stats.skew(ages)}")
print(f"Kurtosis of age is: {stats.kurtosis(ages)}")
# Out:
# Skewness of age is: -0.3245647471718355
# Kurtosis of age is: -1.2938782613522342

# %%
sbn.distplot(ages)

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
ages = [10,13,14,16,15,17,8,13,25,26,29,35,10,4,3,9,5,6]

print(f"Skewness of age is: {stats.skew(ages)}")
print(f"Kurtosis of age is: {stats.kurtosis(ages)}")
# Out:
# Skewness of age is: 0.8293149692155928
# Kurtosis of age is: -0.22709231256239848

# %%
sbn.distplot(ages)

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
